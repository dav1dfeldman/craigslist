# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn import preprocessing
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.linear_model import LinearRegression as LR
from sklearn.linear_model import SGDRegressor as SGD

from sklearn.neighbors import NearestNeighbors

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import Imputer

pd.set_option('display.max_colwidth', 100)
pd.set_option('display.precision', 5)

# %%
df_nei = pd.read_csv('../data/df_neighborhoods.csv')

# %%
df_nei.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26621 entries, 0 to 26620
# Data columns (total 23 columns):
# X             26621 non-null float64
# Y             26621 non-null float64
# apa           26610 non-null object
# bathrooms     25221 non-null float64
# bedrooms      26610 non-null float64
# cats_OK       26621 non-null int64
# date_time     26621 non-null object
# dogs_OK       26621 non-null int64
# furnished     26621 non-null int64
# latitude      26621 non-null float64
# laundry       19599 non-null object
# longitude     26621 non-null float64
# neighborho    26377 non-null object
# no smoking    26621 non-null int64
# parking       16221 non-null object
# post_id       26621 non-null float64
# rent          26621 non-null float64
# sq_ft         12765 non-null float64
# url           26621 non-null object
# wheelchair    26621 non-null int64
# name          26621 non-null object
# LINK          23487 non-null object
# neighbor_2    26621 non-null object
# dtypes: float64(9), int64(5), object(9)
# memory usage: 4.9+ MB

# %%
df_nei = df_nei.drop(['X', 'Y', 'url', 'post_id', 'LINK'], axis = 1)
df_nei = df_nei.rename(columns = {'neighbor_2' : 'N_1', 'name' : 'N_2', 'neighborho' : 'N_user'})

# %%
for N in ['N_1', 'N_2']:
    df_nei[N] = df_nei[N].str.lower()

# %%
df_no_nei = pd.read_csv('../data/df_no_neighborhoods.csv')

# %%
df_no_nei.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2995 entries, 0 to 2994
# Data columns (total 18 columns):
# rent                     2995 non-null float64
# sq_ft                    1528 non-null float64
# bedrooms                 2993 non-null float64
# bathrooms                2837 non-null float64
# neighborhood             2961 non-null object
# latitude                 2672 non-null float64
# longitude                2672 non-null float64
# wheelchair accessible    2995 non-null int64
# no smoking               2995 non-null int64
# furnished                2995 non-null int64
# cats_OK                  2995 non-null int64
# dogs_OK                  2995 non-null int64
# url                      2995 non-null object
# post_id                  2995 non-null int64
# date_time                2995 non-null object
# apa                      2993 non-null object
# laundry                  2266 non-null object
# parking                  1873 non-null object
# dtypes: float64(6), int64(6), object(6)
# memory usage: 444.6+ KB

# %%
df_no_nei = df_no_nei.drop(['url', 'post_id'], axis = 1)
df_no_nei = df_no_nei[df_no_nei.latitude.notnull()].reset_index(drop = True)
df_no_nei = df_no_nei.rename(columns = {'neighborhood' : 'N_user'})

# %%
# %%time
np = df_nei[['latitude', 'longitude', 'N_2']]
X = np.iloc[:,:2].values
y = df_nei.N_2
le = preprocessing.LabelEncoder()
y = le.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 1)
est = RF(n_estimators= 5)
est.fit(X_train, y_train)
y_pred = est.predict(X_test)
score = y_pred - y_test == 0
print 'precent inaccurate: ', float(len(score) - sum(score)) / len(score)
# Out:
# precent inaccurate:  0.0174647887324
# CPU times: user 190 ms, sys: 140 ms, total: 330 ms
# Wall time: 331 ms

# %%
def imputeNeighborhoods(df_nei, df_no_nei, neighborhood, estimators = 5):
    X_train = df_nei[['latitude', 'longitude']].values
    y_train = df_nei[neighborhood]
    X_test = df_no_nei[['latitude', 'longitude']].values
    est = RF(n_estimators= estimators)
    est.fit(X_train, y_train)
    y_pred = est.predict(X_test)
    df_no_nei[neighborhood] = y_pred
    return df_no_nei

# %%
for N in ['N_1', 'N_2']:
    imputeNeighborhoods(df_nei, df_no_nei, N)

# %% [markdown]
# ### Filter out non-SF listings by distance

# %%
def filterDistance(df_with_Ns, df_new, neighbors = 10, distance = .01):
    X = df_with_Ns[['latitude', 'longitude']].values
    X_new = df_new[['latitude', 'longitude']].values
    nbrs = NearestNeighbors(n_neighbors=10, algorithm='ball_tree').fit(X)
    distances, indices = nbrs.kneighbors(X_new)
    df_new['distances'] = pd.DataFrame(distances).mean(axis = 1)
    df_new = df_new[df_new['distances'] < .05].sort(columns = 'distances', ascending = False)
    return df_new

# %%
df_no_nei = filterDistance(df_nei, df_no_nei)

# %%
# check distances

# %%
# temporary - add to function once the right distance is established
df_no_nei = df_no_nei.drop('distances', axis = 1)

# %%
df = pd.concat([df_nei, df_no_nei], axis = 0)

# %%
df = df[df.rent < 10000]
print len(df)
df = df[df.rent > 1000]
print len(df)
df = df[(df.sq_ft < 5000) & ((df.sq_ft != 0)) | (df.sq_ft.isnull())]
print len(df)
df = df.reset_index(drop = True)
# Out:
# 28665
# 28452
# 28444

# %%
N_us = df.N_user.value_counts()
N_user_label = N_us[N_us > (N_us.sum() / 1100)].index

# %%
N_user_unlabel = set(df.N_user.unique()) - set(N_user_label)

# %%
isNullIndex = df[df.N_user.isnull()].index
df.ix[isNullIndex, 'N_user'] = 'nan'

# %%
df[df.N_user.isnull()].N_user.astype
# Out:
# <bound method Series.astype of Series([], name: N_user, dtype: object)>

# %%
label_d = dict(zip(N_user_label,range(len(N_user_label))))

# %%
import numpy as np
unlabel_d = dict(zip(N_user_unlabel, np.zeros(len(N_user_unlabel), dtype = int)))

# %%
label_d.update(unlabel_d)

# %%
df = df.replace({"N_user": label_d})

# %% [markdown]
# ### Filter out perfect scores / repeats

# %%
df['list_count'] = 1

# %%
cols = df.columns[:-1].tolist()

# %%
df_uniq = df.groupby(cols).sum().reset_index().sort(columns = 'date_time')

# %%
im = Imputer(strategy='median', copy = False)
im.fit_transform(df_uniq.sq_ft)
# Out:
# array([[ 1600.,  4490.,  1086., ...,   605.,   911.,  4490.]])

# %%
df_uniq
# Out:
#                          N_1                           N_2 N_user  \
# 25831       western addition         lower pacific heights     21
# 16685        pacific heights               pacific heights      3
# 1853               chinatown            financial district      2
# 22591        south of market               south of market      0
# 12599               nob hill                      nob hill     11
# 4055   downtown/civic center                    tenderloin      6
# 17453               parkside                      parkside      8
# 4056   downtown/civic center                    tenderloin      6
# 9697                 mission                       mission      1
# 8296                  marina                    cow hollow      5
# 24113      visitacion valley             visitacion valley     35
# 10201                mission                       mission      1
# 9335                 mission               dolores heights      1
# 11785               nob hill                      nob hill      2
# 11786               nob hill                      nob hill      2
# 4058   downtown/civic center                    tenderloin      6
# 11443               nob hill                      nob hill      2
# 4057   downtown/civic center                    tenderloin      6
# 5987          haight ashbury               ashbury heights     28
# 8530                  marina                        marina      5
# 14577          outer mission                 outer mission     15
# 14227             ocean view                merced heights      0
# 14121             ocean view                     ingleside     15
# 7784               lakeshore                     lakeshore      8
# 2556   downtown/civic center                  civic center     13
# 7770               lakeshore                     lakeshore      8
# 10999                mission               mission dolores      1
# 16179        pacific heights               pacific heights      3
# 2141   downtown/civic center                cathedral hill      4
# 18290           potrero hill                  potrero hill     10
# ...                      ...                           ...    ...
# 14684          outer mission                     sunnyside     27
# 17194        pacific heights               pacific heights      3
# 627           bernal heights                st. marys park     24
# 4567               excelsior                crocker amazon      0
# 4566               excelsior                crocker amazon      0
# 14725         outer richmond                   lake street     14
# 20241        south of market                   mission bay      0
# 5211      financial district           northern waterfront     16
# 6602          inner richmond                inner richmond      0
# 7560            inner sunset                  inner sunset     17
# 25149       western addition                  lower haight     13
# 22782        south of market               south of market      0
# 22781        south of market               south of market      0
# 4564               excelsior                crocker amazon      0
# 22780        south of market               south of market      0
# 17109        pacific heights               pacific heights      3
# 22779        south of market               south of market      0
# 4563               excelsior                crocker amazon      0
# 25143       western addition  laurel heights / jordan park     25
# 26104       western addition              western addition     21
# 13527             noe valley                    noe valley     12
# 1714     castro/upper market               mission dolores      7
# 1044     castro/upper market                 eureka valley      1
# 17072        pacific heights               pacific heights      3
# 21274        south of market                   rincon hill      0
# 12262               nob hill                      nob hill      2
# 6977          inner richmond                inner richmond     20
# 21273        south of market                   rincon hill      0
# 20280        south of market                   mission bay      0
# 3496   downtown/civic center                lower nob hill      6
#
#                 apa  bathrooms  bedrooms  cats_OK            date_time  \
# 25831     apartment        2.0         3        0  2014-12-03 00:00:00
# 16685     apartment        2.0         2        0  2014-12-04 00:00:00
# 1853          condo        1.5         1        0  2014-12-05 00:00:00
# 22591     apartment        1.0         1        1  2014-12-05 00:00:00
# 12599         condo        1.0         0        1  2014-12-05 00:00:00
# 4055      apartment        1.0         1        1  2014-12-05 00:00:00
# 17453     apartment        1.0         2        1  2014-12-05 00:00:00
# 4056      apartment        1.0         1        1  2014-12-05 00:00:00
# 9697      apartment        1.0         0        0  2014-12-05 00:00:00
# 8296      apartment        2.0         2        1  2014-12-05 00:00:00
# 24113         house        1.0         3        0  2014-12-06 00:00:00
# 10201     apartment        1.0         4        0  2014-12-06 00:00:00
# 9335      apartment        2.0         2        1  2014-12-06 00:00:00
# 11785     apartment        1.0         1        1  2014-12-07 00:00:00
# 11786     apartment        1.0         1        1  2014-12-07 00:00:00
# 4058      apartment        1.0         1        1  2014-12-07 00:00:00
# 11443     apartment        5.0         1        0  2014-12-07 00:00:00
# 4057      apartment        1.0         1        1  2014-12-07 00:00:00
# 5987           flat        2.0         3        0  2014-12-07 00:00:00
# 8530      apartment        1.0         1        0  2014-12-08 00:00:00
# 14577     apartment        1.0         1        1  2014-12-08 00:00:00
# 14227         house        2.0         4        0  2014-12-08 00:00:00
# 14121     apartment        2.5         3        1  2014-12-08 00:00:00
# 7784      apartment        2.0         2        0  2014-12-08 00:00:00
# 2556      apartment        2.0         3        0  2014-12-08 00:00:00
# 7770      apartment        1.0         0        0  2014-12-08 00:00:00
# 11786     detached garage  3400    675           1                      1
# 4058       street parking  2795   4490           0                      1
# 11443       valet parking  3400    675           0                      1
# 4057       street parking  2495   4490           0                      1
# 5987      attached garage  6200   1600           0                      1
# 8530      attached garage  3150    900           0                      1
# 14577     attached garage  2500    600           0                      1
# 14227     attached garage  5000   1431           0                      1
# 14121     attached garage  6195   4490           0                      1
# 7784      attached garage  2899   1115           0                      1
# 2556      attached garage  8000   4490           0                      1
# 7770      attached garage  1889    510           0                      1
# 10999      street parking  4795   4490           0                      1
# 16179     attached garage  4900   1050           0                      1
# 2141              carport  3000   4490           1                      1
# 18290       valet parking  4995   4490           0                      1
# ...                   ...   ...    ...         ...                    ...
# 14684       valet parking  3500   4490           1                      0
# 17194  off-street parking  4250   1350           1                      0
# 627        street parking  3800   4490           1                      0
# 4567      detached garage  3489   1321           1                      0
# 4566      detached garage  3168   1035           1                      0
# 14725       valet parking  2950   4490           1                      0
# 20241     detached garage  4599    940           1                      0
# 5211      detached garage  3537   4490           1                      0
# 6602       street parking  4345    750           1                      0
# 7560        valet parking  2150    600           1                      0
# 25149       valet parking  2700    500           1                      0
# 22782  off-street parking  3115    645           1                      0
# 22781       valet parking  3707   4490           1                      1
# 4564      detached garage  3221   1155           1                      0
# 22780       valet parking  2940    656           1                      1
# 17109     attached garage  8700   1956           1                      0
# 22779       valet parking  2902    656           1                      1
# 4563      detached garage  2520    823           1                      0
# 25143             carport  3850    850           1                      0
# 26104     detached garage  1550    535           1                      0
# 13527     attached garage  4300   1540           1                      0
# 1714   off-street parking  5865    945           1                      1
# 1044        valet parking  3590   1000           1                      0
# 17072     attached garage  4950   1500           1                      0
# 21274       valet parking  3500    605           1                      1
# 12262       valet parking  6000   4490           1                      0
# 6977       street parking  3500   4490           1                      0
# 21273       valet parking  3500    605           1                      1
# 20280     attached garage  3704    911           1                      1
# 3496        valet parking  2895   4490           1                      0
#
#        list_count
# 25831           1
# 16685           1
# 1853            1
# 22591           1
# 12599           1
# 4055            1
# 17453           1
# 4056            1
# 9697            1
# 8296            1
# 24113           1
# 10201           1
# 9335            1
# 11785           1
# 11786           1
# 4058            1
# 11443           1
# 4057            1
# 5987            1
# 8530            1
# 14577           1
# 14227           1
# 14121           1
# 7784            1
# 2556            1
# 7770            1
# 10999           1
# 16179           1
# 2141            1
# 18290           1
# ...           ...
# 14684           1
# 17194           1
# 627             1
# 4567            1
# 4566            1
# 14725           1
# 20241           1
# 5211            1
# 6602            1
# 7560            1
# 25149           1
# 22782           1
# 22781           1
# 4564            1
# 22780           1
# 17109           1
# 22779           1
# 4563            1
# 25143           1
# 26104           1
# 13527           1
# 1714            1
# 1044            1
# 17072           1
# 21274           3
# 12262           2
# 6977            1
# 21273           1
# 20280           1
# 3496            1
#
# [26346 rows x 20 columns]

# %%
for col in df_uniq:
    if df_uniq[col].dtype == object:
        df_uniq[col] = le.fit_transform(df_uniq[col])

# %%
X_cols = df_uniq.drop('rent', axis = 1)
X = X_cols.values

# %%
y = df_uniq.rent

# %%
X_train = X[0:len(X)/2]
y_train = y[0:len(X)/2]
X_test = X[-len(X)/4:]
y_test = y[-len(X)/4:]

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2)

# %%
# %%time
est = RF(n_estimators = 20, n_jobs= -1)
est.fit(X_train, y_train)
y_pred = est.predict(X_test)
# Out:
# CPU times: user 8.82 s, sys: 4.64 s, total: 13.5 s
# Wall time: 7.19 s

# %%
mean_absolute_error(y_pred, y_test)
# Out:
# 641.43904660695307

# %%
perfect_scores = y_pred == y_test

# %%
sum(perfect_scores) / float(len(perfect_scores))
# Out:
# 0.086382268103840892

# %%
sorted(zip(est.feature_importances_, X_cols.columns))[::-1]
# Out:
# [(0.21861716473085541, 'date_time'),
#  (0.12791645832251311, 'longitude'),
#  (0.12684508657941856, 'latitude'),
#  (0.081831593171715705, 'sq_ft'),
#  (0.068492493218115666, 'N_2'),
#  (0.059492841832742005, 'N_user'),
#  (0.052163818356316408, 'N_1'),
#  (0.047043409039529867, 'parking'),
#  (0.032122592290381544, 'bedrooms'),
#  (0.0317648830359454, 'laundry'),
#  (0.029396623323743765, 'no smoking'),
#  (0.02582423647463248, 'apa'),
#  (0.024581478830143111, 'bathrooms'),
#  (0.019610311110495944, 'list_count'),
#  (0.015788146476121194, 'cats_OK'),
#  (0.014968889992675673, 'dogs_OK'),
#  (0.012584797714233206, 'furnished'),
#  (0.010955175500420966, 'wheelchair'),
#  (0.0, 'wheelchair accessible')]

# %%
X_cols
# Out:
#        N_1  N_2  N_user  apa  bathrooms  bedrooms  cats_OK  date_time  \
# 25830   36   55      21    0        2.0         3        0          0
# 16681   24   77       3    0        2.0         2        0          1
# 1855     3   30       2    1        1.5         1        0          2
# 17448   25   80       8    0        1.0         2        1          2
# 4065     6  105       6    0        1.0         1        1          2
# 12598   17   69      11    1        1.0         0        1          2
# 22587   31   97       0    0        1.0         1        1          2
# 4064     6  105       6    0        1.0         1        1          2
# 9697    16   63       1    0        1.0         0        0          2
# 8295    15   20       5    0        2.0         2        1          2
# 10201   16   63       1    0        1.0         4        0          3
# 24108   34  110      35    5        1.0         3        0          3
# 9335    16   24       1    0        2.0         2        1          3
# 5985    11    4      28    4        2.0         3        0          4
# 11784   17   69       2    0        1.0         1        1          4
# 4067     6  105       6    0        1.0         1        1          4
# 11785   17   69       2    0        1.0         1        1          4
# 4066     6  105       6    0        1.0         1        1          4
# 11442   17   69       2    0        5.0         1        0          4
# 10999   16   65       1    0        1.0         2        1          5
# 2562     6   16      13    0        2.0         3        0          5
# 14225   20   58       0    5        2.0         4        0          5
# 7784    14   49       8    0        2.0         2        0          5
# 8528    15   56       5    0        1.0         1        0          5
# 14119   20   42      15    0        2.5         3        1          5
# 14575   21   74      15    0        1.0         1        1          5
# 7770    14   49       8    0        1.0         0        0          5
# 16175   24   77       3    0        1.0         1        0          5
# 8529    15   56       5    0        1.0         1        0          6
# 7771    14   49       8    0        1.0         0        0          6
# ...    ...  ...     ...  ...        ...       ...      ...        ...
# 17105   24   77       3    1        2.5         3        1        136
# 19485   29   91       9    1        1.0         2        0        136
# 21335   31   90       0    1        1.0         1        1        136
# 11661   17   69       2    0        1.0         0        1        136
# 11662   17   69       2    0        1.0         0        1        136
